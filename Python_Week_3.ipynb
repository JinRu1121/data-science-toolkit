# %% [markdown]
# <a href="https://colab.research.google.com/github/JinRu1121/data-science-toolkit/blob/main/Python_Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [3, 12, 14, 6, 9]
list1.append('Science')
print(list1)
# Out:
# [3, 12, 14, 6, 9, 'Science']

# %%
list1.pop(2)
print(list1)
# Out:
# [3, 12, 6, 9, 'Science']

# %%
number = range(6)
print(number)
# Out:
# range(0, 6)

# %%
numbers = list(range(6))
print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
d = {'cat':'cute', 'dog':'furry'}
print(d['cat'])
print('cat'in d)
# Out:
# cute
# True

# %%
print('cute'in d)
# Out:
# False

# %%
print('cute' in d.values())
# Out:
# True

# %%
d['dog'] = 'not furry'
print(d)
# Out:
# {'cat': 'cute', 'dog': 'not furry'}

# %%
del d['cat']
print(d)
# Out:
# {'dog': 'not furry'}
