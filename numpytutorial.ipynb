# %%
import numpy as np

a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
# !mv "../../Colab Notebooks/numpytutorial.ipynb" "./"
# Out:
# mv: cannot stat '../../Colab Notebooks/numpytutorial.ipynb': No such file or directory

# %%
# !ls /content/drive/MyDrive
# Out:
# ls: cannot access '/content/drive/MyDrive': No such file or directory

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/numpytutorial.ipynb" .
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab Notebooks/numpytutorial.ipynb': No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/git_repos/data-science-toolkit
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/git_repos/data-science-toolkit'
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  058b4ea7f5fe49b9a92770dba53161d8680_680.jpg
# '10 OCT F4 BM 【S】 .pdf'
# '1120 (1).jpeg'
#  1120.jpeg
#  15885894997595411767057794096042.jpg
#  15885895299084665887489143952590.jpg
#  15886665931765793945479632089121.jpg
#  15886666402475839350451687962164.jpg
#  15886666661007932186052955774338.jpg
#  15897997820833598138152282761489.jpg
#  15899373506163770593145753921867.jpg
#  15899373652842373427639851016800.jpg
#  15899373862877321792619592570968.jpg
#  15904593872877548986604423101575.jpg
#  15904594646079062036049808278568.jpg
#  15904594889216253698839958923964.jpg
#  15911043252776067708618914818293.jpg
#  15911043697741062805792642098067.jpg
#  15911043945147036347677598356195.jpg
#  15911044304399199181619293241719.jpg
#  1591688700594823259249280897084.jpg
#  15916887170345184879930746344077.jpg
#  15928994095517636574904269165526.jpg
#  15928994234613525277368362233442.jpg
#  15946490447162367556041377084486.jpg
#  15946490937557249582776198759044.jpg
# ...

# %%
# %cd git_repos
# !ls
# Out:
# /content/drive/MyDrive/git_repos
# data-science-toolkit

# %%
# %cd data-science-toolkit
# !pwd
# Out:
# /content/drive/MyDrive/git_repos/data-science-toolkit
# /content/drive/MyDrive/git_repos/data-science-toolkit

# %%
# !ls
# Out:
# 'python_basics (1).ipynb'   python_basics.ipynb   README.md   Tutorial_3.ipynb

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
#  EDA.ipynb		   Python_Script.ipynb	'Untitled (1)'
# 'machine learning.ipynb'   Setup.ipynb		 Untitled1.ipynb
#  Numpy_basics.ipynb	  'Tutorial 3.ipynb'	'Untitled (2)'
#  numpytutorial.ipynb	   Untitled
#  Pandas.ipynb		   Untitled0.ipynb

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/numpytutorial.ipynb" .

# %%
# !ls
# Out:
#  numpytutorial.ipynb	    python_basics.ipynb   Tutorial_3.ipynb
# 'python_basics (1).ipynb'   README.md

# %%
# !git branch
# Out:
# * library/numpy
#   main

# %%
# !git config --global user.name "JinRu1121"
# !git config --global user.email "23116192@siswa.um.edu.my"

# %%
# !git add numpytutorial.ipynb
# !git commit -m "Intro to NumPy"
# Out:
# [library/numpy b55ad76] Intro to NumPy
#  1 file changed, 1 insertion(+)
#  create mode 100644 numpytutorial.ipynb
